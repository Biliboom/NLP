# %%
from BERT_XGBOOST import bert_xgboost

# %% [markdown]
# ### **Note**:
# As you may notice, all confusion matrices are titled identically. To avoid confusion, please note that the first graph represents training on validation data while the second corresponds to the performance on test data

# %% [markdown]
# ### *500 Observation per Class*

# %%
bert_xgboost('imdb_df_500.csv', 500, test= True)
# Out:
# c:\Users\Bijan-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Cleaned 100 records in dataset
# Cleaned 800 records in dataset
# Cleaned 100 records in dataset
# Total number of records: 800
# Num batches: 4
# 100%|██████████| 4/4 [00:00<00:00,  6.04it/s]
# Total number of records: 100
# Num batches: 1
# 100%|██████████| 1/1 [00:00<00:00, 27.78it/s]
# Total number of records: 100
# Num batches: 1
# 100%|██████████| 1/1 [00:00<00:00, 28.45it/s]
# There are 1 GPU(s) available.
# We will use the GPU: NVIDIA GeForce RTX 4080 SUPER
# Training...
# Number of rows in training data: 800
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ...

# %%
bert_xgboost('reddit_df_500.csv', 500, test= True)
# Out:
# c:\Users\Bijan-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Cleaned 150 records in dataset
# Cleaned 1200 records in dataset
# Cleaned 150 records in dataset
# Total number of records: 1200
# Num batches: 5
# 100%|██████████| 5/5 [00:00<00:00, 13.15it/s]
# Total number of records: 150
# Num batches: 1
# 100%|██████████| 1/1 [00:00<00:00, 18.69it/s]
# Total number of records: 150
# Num batches: 1
# 100%|██████████| 1/1 [00:00<00:00, 20.47it/s]
# There are 1 GPU(s) available.
# We will use the GPU: NVIDIA GeForce RTX 4080 SUPER
# Training...
# Number of rows in training data: 1200
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5] END .............eta=0.05, max_depth=5;, score=0.725 total time=   0.8s
# ...

# %%
bert_xgboost('twit_df_500.csv', 500, test= True)
# Out:
# c:\Users\Bijan-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Cleaned 300 records in dataset
# Cleaned 2400 records in dataset
# Cleaned 300 records in dataset
# Total number of records: 2400
# Num batches: 10
# 100%|██████████| 10/10 [00:00<00:00, 25.79it/s]
# Total number of records: 300
# Num batches: 2
# 100%|██████████| 2/2 [00:00<00:00, 36.24it/s]
# Total number of records: 300
# Num batches: 2
# 100%|██████████| 2/2 [00:00<00:00, 34.26it/s]
# There are 1 GPU(s) available.
# We will use the GPU: NVIDIA GeForce RTX 4080 SUPER
# Training...
# Number of rows in training data: 2400
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ...

# %%
bert_xgboost('yelp_df_500.csv', 500, test= True)
# Out:
# c:\Users\Bijan-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Cleaned 250 records in dataset
# Cleaned 2000 records in dataset
# Cleaned 250 records in dataset
# Total number of records: 2000
# Num batches: 8
# 100%|██████████| 8/8 [00:00<00:00, 10.69it/s]
# Total number of records: 250
# Num batches: 1
# 100%|██████████| 1/1 [00:00<00:00, 10.34it/s]
# Total number of records: 250
# Num batches: 1
# 100%|██████████| 1/1 [00:00<00:00, 10.67it/s]
# There are 1 GPU(s) available.
# We will use the GPU: NVIDIA GeForce RTX 4080 SUPER
# Training...
# Number of rows in training data: 2000
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5] END .............eta=0.05, max_depth=5;, score=0.704 total time=   1.5s
# ...

# %% [markdown]
# ### *3500 Observation per Class*

# %%
bert_xgboost('imdb_df_3500.csv', 3500, test= True)
# Out:
# c:\Users\Bijan-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Cleaned 700 records in dataset
# Cleaned 5600 records in dataset
# Cleaned 700 records in dataset
# Total number of records: 5600
# Num batches: 22
# 100%|██████████| 22/22 [00:01<00:00, 12.08it/s]
# Total number of records: 700
# Num batches: 3
# 100%|██████████| 3/3 [00:00<00:00, 12.30it/s]
# Total number of records: 700
# Num batches: 3
# 100%|██████████| 3/3 [00:00<00:00, 12.45it/s]
# There are 1 GPU(s) available.
# We will use the GPU: NVIDIA GeForce RTX 4080 SUPER
# Training...
# Number of rows in training data: 5600
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ...

# %%
bert_xgboost('reddit_df_3500.csv', 3500, test= True)
# Out:
# c:\Users\Bijan-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Cleaned 1050 records in dataset
# Cleaned 8400 records in dataset
# Cleaned 1050 records in dataset
# Total number of records: 8400
# Num batches: 33
# 100%|██████████| 33/33 [00:02<00:00, 12.30it/s]
# Total number of records: 1050
# Num batches: 5
# 100%|██████████| 5/5 [00:00<00:00, 15.34it/s]
# Total number of records: 1050
# Num batches: 5
# 100%|██████████| 5/5 [00:00<00:00, 15.39it/s]
# There are 1 GPU(s) available.
# We will use the GPU: NVIDIA GeForce RTX 4080 SUPER
# Training...
# Number of rows in training data: 8400
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ...

# %%
bert_xgboost('twit_df_3500.csv', 3500, test = True)
# Out:
# c:\Users\Bijan-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Cleaned 2100 records in dataset
# Cleaned 16800 records in dataset
# Cleaned 2100 records in dataset
# Total number of records: 16800
# Num batches: 66
# 100%|██████████| 66/66 [00:02<00:00, 26.93it/s]
# Total number of records: 2100
# Num batches: 9
# 100%|██████████| 9/9 [00:00<00:00, 28.25it/s]
# Total number of records: 2100
# Num batches: 9
# 100%|██████████| 9/9 [00:00<00:00, 28.83it/s]
# There are 1 GPU(s) available.
# We will use the GPU: NVIDIA GeForce RTX 4080 SUPER
# Training...
# Number of rows in training data: 16800
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ...

# %%
bert_xgboost('yelp_df_3500.csv', 3500, test = True)
# Out:
# c:\Users\Bijan-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Cleaned 1750 records in dataset
# Cleaned 14000 records in dataset
# Cleaned 1750 records in dataset
# Total number of records: 14000
# Num batches: 55
# 100%|██████████| 55/55 [00:05<00:00, 10.62it/s]
# Total number of records: 1750
# Num batches: 7
# 100%|██████████| 7/7 [00:00<00:00, 11.33it/s]
# Total number of records: 1750
# Num batches: 7
# 100%|██████████| 7/7 [00:00<00:00, 10.62it/s]
# There are 1 GPU(s) available.
# We will use the GPU: NVIDIA GeForce RTX 4080 SUPER
# Training...
# Number of rows in training data: 14000
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ...

# %% [markdown]
# ### *7852 Observations per Class*

# %%
bert_xgboost('imdb_df_7852.csv', 7852, test= True)
# Out:
# c:\Users\Bijan-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Cleaned 1571 records in dataset
# Cleaned 12562 records in dataset
# Cleaned 1571 records in dataset
# Total number of records: 12562
# Num batches: 50
# 100%|██████████| 50/50 [00:04<00:00, 10.35it/s]
# Total number of records: 1571
# Num batches: 7
# 100%|██████████| 7/7 [00:00<00:00, 12.66it/s]
# Total number of records: 1571
# Num batches: 7
# 100%|██████████| 7/7 [00:00<00:00, 12.61it/s]
# There are 1 GPU(s) available.
# We will use the GPU: NVIDIA GeForce RTX 4080 SUPER
# Training...
# Number of rows in training data: 12562
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ...

# %%
bert_xgboost('reddit_df_7852.csv', 7852, test= True)
# Out:
# c:\Users\Bijan-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Cleaned 2356 records in dataset
# Cleaned 18844 records in dataset
# Cleaned 2356 records in dataset
# Total number of records: 18844
# Num batches: 74
# 100%|██████████| 74/74 [00:05<00:00, 12.43it/s]
# Total number of records: 2356
# Num batches: 10
# 100%|██████████| 10/10 [00:00<00:00, 14.04it/s]
# Total number of records: 2356
# Num batches: 10
# 100%|██████████| 10/10 [00:00<00:00, 14.12it/s]
# There are 1 GPU(s) available.
# We will use the GPU: NVIDIA GeForce RTX 4080 SUPER
# Training...
# Number of rows in training data: 18844
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ...

# %%
bert_xgboost('twit_df_7852.csv', 7852, test= True)
# Out:
# c:\Users\Bijan-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Cleaned 4712 records in dataset
# Cleaned 37689 records in dataset
# Cleaned 4711 records in dataset
# Total number of records: 37689
# Num batches: 148
# 100%|██████████| 148/148 [00:05<00:00, 29.03it/s]
# Total number of records: 4712
# Num batches: 19
# 100%|██████████| 19/19 [00:00<00:00, 28.80it/s]
# Total number of records: 4711
# Num batches: 19
# 100%|██████████| 19/19 [00:00<00:00, 24.81it/s]
# There are 1 GPU(s) available.
# We will use the GPU: NVIDIA GeForce RTX 4080 SUPER
# Training...
# Number of rows in training data: 37689
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ...

# %%
bert_xgboost('yelp_df_7852.csv', 7852, test= True)
# Out:
# c:\Users\Bijan-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Cleaned 3926 records in dataset
# Cleaned 31408 records in dataset
# Cleaned 3926 records in dataset
# Total number of records: 31408
# Num batches: 123
# 100%|██████████| 123/123 [00:10<00:00, 11.94it/s]
# Total number of records: 3926
# Num batches: 16
# 100%|██████████| 16/16 [00:01<00:00, 12.45it/s]
# Total number of records: 3926
# Num batches: 16
# 100%|██████████| 16/16 [00:01<00:00, 11.29it/s]
# There are 1 GPU(s) available.
# We will use the GPU: NVIDIA GeForce RTX 4080 SUPER
# Training...
# Number of rows in training data: 31408
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ...
