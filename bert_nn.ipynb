# %%
from BERT_NN import bert_nn

# %% [markdown]
# ### **Note**:
# As you may notice, all confusion matrices are titled identically. To avoid confusion, please note that the first two graphs represent the first and second epoch of training on validation data. The third graph corresponds to the performance on test data

# %% [markdown]
# ### *500 Observation per Class*

# %%
bert_nn('imdb_df_500.csv', 500, test= True)
# Out:
# There are 1 GPU(s) available.
# We will use the GPU: NVIDIA GeForce RTX 4080 SUPER
# c:\Users\Bijan-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Token indices sequence length is longer than the specified maximum sequence length for this model (542 > 512). Running this sequence through the model will result in indexing errors
# Max length:  512
# Tokenizing data...
# ...

# %%
bert_nn('reddit_df_500.csv', 500, test= True)
# Out:
# There are 1 GPU(s) available.
# We will use the GPU: NVIDIA GeForce RTX 4080 SUPER
# c:\Users\Bijan-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Token indices sequence length is longer than the specified maximum sequence length for this model (625 > 512). Running this sequence through the model will result in indexing errors
# Max length:  512
# Tokenizing data...
# ...

# %%
bert_nn('twit_df_500.csv', 500, test= True)
# Out:
# There are 1 GPU(s) available.
# We will use the GPU: NVIDIA GeForce RTX 4080 SUPER
# c:\Users\Bijan-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Max length:  75
# Tokenizing data...
# c:\Users\Bijan-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\tokenization_utils_base.py:2674: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
# ...

# %%
bert_nn('yelp_df_500.csv', 500, test= True)
# Out:
# c:\Users\Bijan-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Token indices sequence length is longer than the specified maximum sequence length for this model (545 > 512). Running this sequence through the model will result in indexing errors
# There are 1 GPU(s) available.
# We will use the GPU: NVIDIA GeForce RTX 4080 SUPER
# Max length:  512
# Tokenizing data...
# ...

# %% [markdown]
# ### *3500 Observation per Class*

# %%
bert_nn('imdb_df_3500.csv', 3500, test= True)
# Out:
# There are 1 GPU(s) available.
# We will use the GPU: NVIDIA GeForce RTX 4080 SUPER
# c:\Users\Bijan-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Token indices sequence length is longer than the specified maximum sequence length for this model (542 > 512). Running this sequence through the model will result in indexing errors
# Max length:  512
# Tokenizing data...
# ...

# %%
bert_nn('reddit_df_3500.csv', 3500, test= True)

# %%
bert_nn('twit_df_3500.csv', 3500, test = True)

# %%
bert_nn('yelp_df_3500.csv', 3500, test = True)

# %% [markdown]
# ### *7852 Observations per Class*

# %%
bert_nn('imdb_df_7852.csv', 7852, test= True)

# %%
bert_nn('reddit_df_7852.csv', 7852, test= True)

# %%
bert_nn('twit_df_7852.csv', 7852, test= True)
# Out:
# There are 1 GPU(s) available.
# We will use the GPU: NVIDIA GeForce RTX 4080 SUPER
# c:\Users\Bijan-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Max length:  106
# Tokenizing data...
# c:\Users\Bijan-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\tokenization_utils_base.py:2674: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
# ...

# %%
bert_nn('yelp_df_7852.csv', 7852, test= True)
# Out:
# c:\Users\Bijan-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Token indices sequence length is longer than the specified maximum sequence length for this model (545 > 512). Running this sequence through the model will result in indexing errors
# There are 1 GPU(s) available.
# We will use the GPU: NVIDIA GeForce RTX 4080 SUPER
# Max length:  512
# Tokenizing data...
# ...
