# %%
from BERT_RF import bert_rf

# %% [markdown]
# ### **Note**:
# As you may notice, all confusion matrices are titled identically. To avoid confusion, please note that the first graph represents training on validation data while the second corresponds to the performance on test data

# %% [markdown]
# ### *500 Observation per Class*

# %%
bert_rf('imdb_df_500.csv', 500, test= True)
# Out:
# c:\Users\Bijan-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Cleaned 100 records in dataset
# Cleaned 800 records in dataset
# Cleaned 100 records in dataset
# Total number of records: 800
# Num batches: 4
# 100%|██████████| 4/4 [00:05<00:00,  1.32s/it]
# Total number of records: 100
# Num batches: 1
# 100%|██████████| 1/1 [00:00<00:00,  1.72it/s]
# Total number of records: 100
# Num batches: 1
# 100%|██████████| 1/1 [00:00<00:00,  1.77it/s]
# Training...
# Number of rows in training data: 800
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END .......................max_depth=3;, score=0.791 total time=   0.1s
# [CV 2/5] END .......................max_depth=3;, score=0.707 total time=   0.1s
# ...

# %%
bert_rf('reddit_df_500.csv', 500, test= True)
# Out:
# c:\Users\Bijan-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Cleaned 150 records in dataset
# Cleaned 1200 records in dataset
# Cleaned 150 records in dataset
# Total number of records: 1200
# Num batches: 5
# 100%|██████████| 5/5 [00:08<00:00,  1.69s/it]
# Total number of records: 150
# Num batches: 1
# 100%|██████████| 1/1 [00:01<00:00,  1.00s/it]
# Total number of records: 150
# Num batches: 1
# 100%|██████████| 1/1 [00:00<00:00,  1.01it/s]
# Training...
# Number of rows in training data: 1200
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END .......................max_depth=3;, score=0.717 total time=   0.2s
# [CV 2/5] END .......................max_depth=3;, score=0.668 total time=   0.2s
# ...

# %%
bert_rf('twit_df_500.csv', 500, test= True)
# Out:
# c:\Users\Bijan-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Cleaned 300 records in dataset
# Cleaned 2400 records in dataset
# Cleaned 300 records in dataset
# Total number of records: 2400
# Num batches: 10
# 100%|██████████| 10/10 [00:07<00:00,  1.37it/s]
# Total number of records: 300
# Num batches: 2
# 100%|██████████| 2/2 [00:00<00:00,  2.07it/s]
# Total number of records: 300
# Num batches: 2
# 100%|██████████| 2/2 [00:00<00:00,  2.16it/s]
# Training...
# Number of rows in training data: 2400
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END .......................max_depth=3;, score=0.761 total time=   0.5s
# [CV 2/5] END .......................max_depth=3;, score=0.749 total time=   0.5s
# ...

# %%
bert_rf('yelp_df_500.csv', 500, test= True)
# Out:
# c:\Users\Bijan-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Cleaned 250 records in dataset
# Cleaned 2000 records in dataset
# Cleaned 250 records in dataset
# Total number of records: 2000
# Num batches: 8
# 100%|██████████| 8/8 [00:12<00:00,  1.61s/it]
# Total number of records: 250
# Num batches: 1
# 100%|██████████| 1/1 [00:01<00:00,  1.48s/it]
# Total number of records: 250
# Num batches: 1
# 100%|██████████| 1/1 [00:01<00:00,  1.49s/it]
# Training...
# Number of rows in training data: 2000
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END .......................max_depth=3;, score=0.687 total time=   0.4s
# [CV 2/5] END .......................max_depth=3;, score=0.687 total time=   0.4s
# ...

# %% [markdown]
# ### *3500 Observation per Class*

# %%
bert_rf('imdb_df_3500.csv', 3500, test= True)
# Out:
# c:\Users\Bijan-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Cleaned 700 records in dataset
# Cleaned 5600 records in dataset
# Cleaned 700 records in dataset
# Total number of records: 5600
# Num batches: 22
# 100%|██████████| 22/22 [00:32<00:00,  1.50s/it]
# Total number of records: 700
# Num batches: 3
# 100%|██████████| 3/3 [00:03<00:00,  1.30s/it]
# Total number of records: 700
# Num batches: 3
# 100%|██████████| 3/3 [00:03<00:00,  1.29s/it]
# Training...
# Number of rows in training data: 5600
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END .......................max_depth=3;, score=0.793 total time=   1.3s
# [CV 2/5] END .......................max_depth=3;, score=0.789 total time=   1.3s
# ...

# %%
bert_rf('reddit_df_3500.csv', 3500, test= True)
# Out:
# c:\Users\Bijan-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Cleaned 1050 records in dataset
# Cleaned 8400 records in dataset
# Cleaned 1050 records in dataset
# Total number of records: 8400
# Num batches: 33
# 100%|██████████| 33/33 [00:59<00:00,  1.81s/it]
# Total number of records: 1050
# Num batches: 5
# 100%|██████████| 5/5 [00:07<00:00,  1.51s/it]
# Total number of records: 1050
# Num batches: 5
# 100%|██████████| 5/5 [00:07<00:00,  1.45s/it]
# Training...
# Number of rows in training data: 8400
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END .......................max_depth=3;, score=0.709 total time=   2.1s
# ...

# %%
bert_rf('twit_df_3500.csv', 3500, test = True)
# Out:
# c:\Users\Bijan-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Cleaned 2100 records in dataset
# Cleaned 16800 records in dataset
# Cleaned 2100 records in dataset
# Total number of records: 16800
# Num batches: 66
# 100%|██████████| 66/66 [00:46<00:00,  1.41it/s]
# Total number of records: 2100
# Num batches: 9
# 100%|██████████| 9/9 [00:06<00:00,  1.46it/s]
# Total number of records: 2100
# Num batches: 9
# 100%|██████████| 9/9 [00:06<00:00,  1.50it/s]
# Training...
# Number of rows in training data: 16800
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END .......................max_depth=3;, score=0.761 total time=   4.3s
# ...

# %%
bert_rf('yelp_df_3500.csv', 3500, test = True)
# Out:
# c:\Users\Bijan-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Cleaned 1750 records in dataset
# Cleaned 14000 records in dataset
# Cleaned 1750 records in dataset
# Total number of records: 14000
# Num batches: 55
# 100%|██████████| 55/55 [01:29<00:00,  1.63s/it]
# Total number of records: 1750
# Num batches: 7
# 100%|██████████| 7/7 [00:11<00:00,  1.58s/it]
# Total number of records: 1750
# Num batches: 7
# 100%|██████████| 7/7 [00:10<00:00,  1.55s/it]
# Training...
# Number of rows in training data: 14000
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END .......................max_depth=3;, score=0.724 total time=   3.5s
# ...

# %% [markdown]
# ### *7852 Observations per Class*

# %%
bert_rf('imdb_df_7852.csv', 7852, test= True)
# Out:
# c:\Users\Bijan-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Cleaned 1571 records in dataset
# Cleaned 12562 records in dataset
# Cleaned 1571 records in dataset
# Total number of records: 12562
# Num batches: 50
# 100%|██████████| 50/50 [02:38<00:00,  3.16s/it]
# Total number of records: 1571
# Num batches: 7
# 100%|██████████| 7/7 [00:22<00:00,  3.27s/it]
# Total number of records: 1571
# Num batches: 7
# 100%|██████████| 7/7 [00:22<00:00,  3.26s/it]
# Training...
# Number of rows in training data: 12562
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END .......................max_depth=3;, score=0.784 total time=   4.6s
# ...

# %%
bert_rf('reddit_df_7852.csv', 7852, test= True)
# Out:
# c:\Users\Bijan-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Cleaned 2356 records in dataset
# Cleaned 18844 records in dataset
# Cleaned 2356 records in dataset
# Total number of records: 18844
# Num batches: 74
# 100%|██████████| 74/74 [02:14<00:00,  1.81s/it]
# Total number of records: 2356
# Num batches: 10
# 100%|██████████| 10/10 [00:17<00:00,  1.70s/it]
# Total number of records: 2356
# Num batches: 10
# 100%|██████████| 10/10 [00:16<00:00,  1.67s/it]
# Training...
# Number of rows in training data: 18844
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END .......................max_depth=3;, score=0.716 total time=   4.8s
# ...

# %%
bert_rf('twit_df_7852.csv', 7852, test= True)
# Out:
# c:\Users\Bijan-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Cleaned 4712 records in dataset
# Cleaned 37689 records in dataset
# Cleaned 4711 records in dataset
# Total number of records: 37689
# Num batches: 148
# 100%|██████████| 148/148 [01:46<00:00,  1.39it/s]
# Total number of records: 4712
# Num batches: 19
# 100%|██████████| 19/19 [00:13<00:00,  1.37it/s]
# Total number of records: 4711
# Num batches: 19
# 100%|██████████| 19/19 [00:12<00:00,  1.49it/s]
# Training...
# Number of rows in training data: 37689
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END .......................max_depth=3;, score=0.750 total time=  10.1s
# ...

# %%
bert_rf('yelp_df_7852.csv', 7852, test= True)
# Out:
# c:\Users\Bijan-PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Cleaned 3926 records in dataset
# Cleaned 31408 records in dataset
# Cleaned 3926 records in dataset
# Total number of records: 31408
# Num batches: 123
# 100%|██████████| 123/123 [03:23<00:00,  1.65s/it]
# Total number of records: 3926
# Num batches: 16
# 100%|██████████| 16/16 [00:25<00:00,  1.61s/it]
# Total number of records: 3926
# Num batches: 16
# 100%|██████████| 16/16 [00:25<00:00,  1.58s/it]
# Training...
# Number of rows in training data: 31408
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END .......................max_depth=3;, score=0.718 total time=   8.2s
# ...
